# %% [markdown]
# <a href="https://colab.research.google.com/github/joyc3lin/datasci_7_geospatial/blob/main/HHA507assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd

# %% [markdown]
# ## **Dataset 1: Health Insurance Coverage**

# %%
#loading dataset in
df1 = gpd.read_file('HealthInsuranceCoverage.geojson')
df1
# Out:
#      OBJECTID  GEOID10  TotalCivilianPop  WithHealthInsurance  \
# 0           1  2648371             23014                21364
# 1           2  2648380              7064                 6716
# 2           3  2648081             20565                18725
# 3           4  2648315             26833                25097
# 4           5  2648317             26511                23397
# ..        ...      ...               ...                  ...
# 173       174  2648124             30505                27822
# 174       175  2648183             42363                39498
# 175       176  2648154             37431                35536
# 176       177  2648240             17463                15065
# 177       178  2648125             19815                16902
#
#      NoHealthInsurance  Pct_Insured  WithInsurance_U18  NoInsurance_U18  \
# 0                 1650     0.928305               5789              123
# 1                  348     0.950736               1608               33
# ...

# %%
# checking shape
df1.shape
# Out:
# (178, 10)

# %%
# looking for missing values
missing_values = df1.isnull().sum()
missing_values
# Out:
# OBJECTID               0
# GEOID10                0
# TotalCivilianPop       0
# WithHealthInsurance    0
# NoHealthInsurance      0
# Pct_Insured            4
# WithInsurance_U18      0
# NoInsurance_U18        0
# Pct_Insured_U18        4
# geometry               0
# dtype: int64

# %%
# checking column names
df1.columns
# Out:
# Index(['OBJECTID', 'GEOID10', 'TotalCivilianPop', 'WithHealthInsurance',
#        'NoHealthInsurance', 'Pct_Insured', 'WithInsurance_U18',
#        'NoInsurance_U18', 'Pct_Insured_U18', 'geometry'],
#       dtype='object')

# %%
# map visualization
df1.plot("WithHealthInsurance", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **Insights**
#
# **Dataset Description:**
#
# and  its attributes
#
# **Patterns or Anomalies:**
#
# **Visualization Decisions:**
#  (e.g., choice of specific colors or markers

# %% [markdown]
# ---
#
# </br>
#
# ## **Dataset 2: Birth Statistics**

# %%
#loading dataset in
df2 = gpd.read_file('Birth_Statistics.geojson')
df2
# Out:
#     FID    ZIP       LBW   Preterm  TeenBirth  Birth_Rate  F1stTriCare  \
# 0     1  60002  0.084837  0.134124       18.5   10.440239    74.639700
# 1     2  60010  0.052208  0.080828        1.4    3.219561    86.189946
# 2     3  60015  0.095519  0.101959        1.8    7.635261    83.544132
# 3     4  60020  0.077067  0.087777       29.9   13.737068    79.075398
# 4     5  60030  0.071311  0.086675        6.2   10.598146    81.745316
# 5     6  60031  0.081407  0.098994       10.1   10.265032    78.372131
# 6     7  60035  0.067941  0.088888        3.6    8.161008    84.821850
# 7     8  60040  0.081060  0.116597       21.7   14.259259    81.801379
# 8     9  60042  0.057217  0.103992        5.2    5.142590    74.762789
# 9    10  60044  0.045741  0.077593        4.8    8.494268    84.421498
# 10   11  60045  0.048820  0.076689        0.3    4.886430    84.572198
# 11   12  60046  0.068126  0.085630        9.1   10.183884    80.923184
# ...

# %%
# checking shape
df2.shape
# Out:
# (27, 10)

# %%
# looking for missing values
missing_values = df2.isnull().sum()
missing_values
# Out:
# FID             0
# ZIP             0
# LBW             0
# Preterm         0
# TeenBirth       0
# Birth_Rate      0
# F1stTriCare     0
# SHAPE_Length    0
# SHAPE_Area      0
# geometry        0
# dtype: int64

# %%
# checking column names
df2.columns
# Out:
# Index(['FID', 'ZIP', 'LBW', 'Preterm', 'TeenBirth', 'Birth_Rate',
#        'F1stTriCare', 'SHAPE_Length', 'SHAPE_Area', 'geometry'],
#       dtype='object')

# %%
# map visualization
df2.plot("TeenBirth", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **Insights**
#
# **Dataset Description:**
#
# and  its attributes
#
# **Patterns or Anomalies:**
#
# **Visualization Decisions:**
#  (e.g., choice of specific colors or markers

# %% [markdown]
# ---
#
# </br>
#
# ## **Dataset 3: Development Tracking**

# %%
#loading dataset in
df3 = gpd.read_file('Development_Tracking.geojson')
df3
# Out:
#       OBJECTID  CALCACREAG PARNO MAPNUMBER     MAP_PARCEL      CNTRL_NO  \
# 0            3    0.982800  None      None  0150000001920  1.500000e+11
# 1            4    1.444409  None      None  0460000000430  4.600000e+11
# 2            6    2.645259  None      None  0340000002030  3.400000e+11
# 3            9    0.904395  None      None  0460000000361  4.600000e+11
# 4           10   12.548247  None   0870000  0870000000640  8.700000e+11
# ...        ...         ...   ...       ...            ...           ...
# 3457    108149         NaN   12B      None  0090000000122  9.000000e+10
# 3458    108150         NaN   31B      None  0630000000312  6.300000e+11
# 3459    108151         NaN   372      None  0360000003720  3.600000e+11
# 3460    108550         NaN   156      None  0460000001560  4.600000e+11
# 3461    108551         NaN    42      None  1470000000420  1.470000e+12
#
#             TYPE_         APPLICATIO                   PROJECT_NA  \
# ...

# %%
# checking shape
df3.shape
# Out:
# (3462, 39)

# %%
# looking for missing values
missing_values = df3.isnull().sum()
missing_values
# Out:
# OBJECTID               0
# CALCACREAG          2008
# PARNO               1915
# MAPNUMBER           2445
# MAP_PARCEL           650
# CNTRL_NO             665
# TYPE_                  0
# APPLICATIO             0
# PROJECT_NA           626
# ST_ADD               790
# RESULTS                6
# ZONING_FRO          1278
# ZONING_TO           1499
# HOUSING_UN          1311
# CCACTDATE           2036
# CC_ACTION            835
# PC_ACTION           1370
# PCACTDATE           1802
# ARCACTDATE          2935
# ARC_ACTION          2095
# AGE_RESTRI          1943
# AGE_REST_2          1977
# FINALAPPRO             0
# DATEOFAPPL          1166
# INLOS                  2
# ENTEREDDT           1956
# CREATED_USER        1405
# CREATED_DATE        1405
# LAST_EDITED_USER       0
# LAST_EDITED_DATE       0
# PLANNER             2276
# RESIDENTIAL            4
# STF_RCMNDTNS        2346
# FINALACTIONDATE      342
# DATECERTPH          3004
# EBUILD_LINK         2915
# SHAPESTArea            0
# ...

# %%
# checking column names
df3.columns
# Out:
# Index(['OBJECTID', 'CALCACREAG', 'PARNO', 'MAPNUMBER', 'MAP_PARCEL',
#        'CNTRL_NO', 'TYPE_', 'APPLICATIO', 'PROJECT_NA', 'ST_ADD', 'RESULTS',
#        'ZONING_FRO', 'ZONING_TO', 'HOUSING_UN', 'CCACTDATE', 'CC_ACTION',
#        'PC_ACTION', 'PCACTDATE', 'ARCACTDATE', 'ARC_ACTION', 'AGE_RESTRI',
#        'AGE_REST_2', 'FINALAPPRO', 'DATEOFAPPL', 'INLOS', 'ENTEREDDT',
#        'CREATED_USER', 'CREATED_DATE', 'LAST_EDITED_USER', 'LAST_EDITED_DATE',
#        'PLANNER', 'RESIDENTIAL', 'STF_RCMNDTNS', 'FINALACTIONDATE',
#        'DATECERTPH', 'EBUILD_LINK', 'SHAPESTArea', 'SHAPESTLength',
#        'geometry'],
#       dtype='object')

# %%
# map visualization
df3.plot("FINALAPPRO", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **Insights**
#
# **Dataset Description:**
#
# and  its attributes
#
# **Patterns or Anomalies:**
#
# **Visualization Decisions:**
#  (e.g., choice of specific colors or markers

# %% [markdown]
# ---
#
# </br>
#
# ## **Dataset 4: Residential Boundaries**

# %%
#loading dataset in
df4 = gpd.read_file('residential-boundaries.geojson')
df4
# Out:
#                                       name                category  \
# 0                            Kistler Court  Single-Family Detached
# 1                               Carrington  Single-Family Detached
# 2                                Southwick  Single-Family Detached
# 3                         Falconer's Ridge  Single-Family Detached
# 4                             North Meadow  Single-Family Detached
# ..                                     ...                     ...
# 758                             Autumnwood  Single-Family Detached
# 759                 Walker Apartments, The               Apartment
# 760               Shelbourne Senior Living    Retirement Community
# 761  Stoneridge Gracious Retirement Living    Retirement Community
# 762                 The Reserve at Wackena  Single-Family Detached
#
#      approvedlots             description  shape_starea  shape_stlength  \
# 0             6.0  Single-Family Detached  3.217480e+05     2299.439930
# ...

# %%
# checking shape
df4.shape
# Out:
# (763, 10)

# %%
# looking for missing values
missing_values = df4.isnull().sum()
missing_values
# Out:
# name                0
# category            9
# approvedlots       23
# description        54
# shape_starea        0
# shape_stlength      0
# hoaactive         212
# geo_shape         763
# geo_point_2d        5
# geometry            5
# dtype: int64

# %%
# map visualization
df4.plot("shape_starea", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **Insights**
#
# **Dataset Description:**
#
# and  its attributes
#
# **Patterns or Anomalies:**
#
# **Visualization Decisions:**
#  (e.g., choice of specific colors or markers

# %% [markdown]
# ---
#
# </br>
#
# ## **Dataset 5: Birth Statistics**

# %%
#loading dataset in
df5 = gpd.read_file('Average_Date_When_Lilacs_Bloom_in_Idaho.geojson')
df5
# Out:
#     OBJECTID      DATE  SHAPE_Length  SHAPE_Area  \
# 0          1   June 14      2.740956    0.154356
# 1          2   June 24      1.213715    0.034333
# 2          3    May 30      4.948964    0.351489
# 3          4    May 18      1.899916    0.020063
# 4          5    May 15      1.607627    0.068717
# 5          6    May 18      1.074441    0.007127
# 6          7    May 30      1.043042    0.038555
# 7          8   June 14      0.730671    0.016816
# 8          9   June 29      0.568234    0.014500
# 9         10   June 09      0.610275    0.024058
# 10        11    May 18      3.053703    0.183654
# 11        12    May 30     75.605940    6.822987
# 12        13    May 15      0.380205    0.007997
# 13        14   June 09      1.543397    0.057825
# 14        15    May 18     74.307828    1.452491
# 15        16    May 15      4.389877    0.224401
# 16        17    May 18      0.696979    0.017270
# 17        18   June 14     53.627170    3.763981
# ...

# %%
# checking shape
df5.shape
# Out:
# (60, 5)

# %%
# looking for missing values
missing_values = df5.isnull().sum()
missing_values
# Out:
# OBJECTID        0
# DATE            0
# SHAPE_Length    0
# SHAPE_Area      0
# geometry        0
# dtype: int64

# %%
# map visualization
df5.plot("DATE", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **Insights**
#
# **Dataset Description:**
#
# and  its attributes
#
# **Patterns or Anomalies:**
#
# **Visualization Decisions:**
#  (e.g., choice of specific colors or markers
